# %% [markdown]
# # Merge all data sets

# %% [markdown]
# Earnings from yahoo.com, metrics from stockrow.com, and sector/industries from marketwatch.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tickerlist import make_list
import re
import pickle
import json

# %% [markdown]
# ## Clean sector and industry data set

# %%
sectors = {'consumer_discr': ['Computers/Consumer Electronics', 'Mixed Retailing', 'Home Goods Retail', 'Broadcasting', 'Restaurants', 'Tourism', 'Footwear', 'Automobiles', 'Toys & Games', 'Clothing Retail', 'Hotels', 'Auto & Commercial Vehicle Parts', 'Commercial Vehicles', 'Housewares', 'Specialty Retail', 'Clothing', 'Advertising/Marketing/Public Relations', 'Publishing', 'Gambling Industries', 'Residential Building Construction', 'Tires', 'Furniture'],
           'conumser_staples': ['Personal Care Products/Appliances', 'Non-Alcoholic Beverages/Drinks', 'Tobacco', 'Drug Retail', 'Food Retail', 'Food Products', 'Nondurable Household Products', 'Alcoholic Beverages/Drinks'],
           'energy': ['Major Oil & Gas', 'Oil & Gas Products/Services', 'Oil Extraction', 'Pipeline Transportation'],
           'financials': ['Reinsurance', 'Major International Banks', 'Banking', 'Diversified Holding Companies', 'Consumer Finance', 'Life Insurance', 'Securities', 'Finance Companies', 'Non-Life Insurance', 'Investment Advisors', 'Full-Line Insurance', 'Accounting', 'Insurance Brokering', 'Savings Institutions'],
           'health_care': ['Pharmaceuticals', 'Biotechnology', 'Medical Equipment/Supplies', 'Precision Products', 'Healthcare Provision', ],
           'industrials': ['Aerospace Products/Parts', 'Railroads', 'Air Freight', 'Defense Equipment/Products', 'Mobile Machinery', 'Farming', 'Industrial Machinery', 'Passenger Airlines', 'Environment/Waste Management', 'Industrial Products', 'Building Materials/Products', 'Wholesalers', 'General Services', 'Transportation Services', 'Trucking', 'Technical Services', 'Employment/Training Services', 'Construction'],
           'info_tech': ['Software', 'Internet/Online', 'Semiconductors', 'Networking', 'Computer Services', 'Diversified Business Services', 'Industrial Electronics'],
           'materials': ['Chemicals', 'Paper/Pulp', 'Gold', 'Non-Ferrous Metals', 'Iron/Steel', 'Containers/Packaging'],
           'real_estate': ['Specialty REITs', 'Retail REITs', 'Industrial/Office REITs', 'Healthcare REITs', 'Residential REITs', 'Hotel/Lodging REITs', 'Diversified REITs', 'Real Estate Developers'],
           'telecomm': ['Wireless Telecommunications Services', 'Wired Telecommunications Services'],
           'utilities': ['Electric Utilities', 'Multiutilities', 'Gas Utilities', 'Water Utilities']}

# %% [markdown]
# ### Replace marketwatch sectors with official GISC sectors

# %%
with open('/Users/samfunk/ds/metis/project_mcnulty/datafiles/sector_industries.pkl', 'rb') as f:
    sect_ind_dict = pickle.load(f)

sector_industry_raw = pd.DataFrame.from_dict(sect_ind_dict, orient='index')
sect_ind_df = pd.DataFrame(columns=['mw_sector', 'industry', 'true_sector'])

for ticker in sector_industry_raw.index:
    true_sector = [k for k,v in sectors.items() if sector_industry_raw.loc[ticker][1] in v]
    for i in range(1,5):
        sect_ind_df.loc['%s_%d' % (ticker, i)] = sector_industry_raw.loc[ticker].tolist() + true_sector

# %%
len(sect_ind_df)
# Out:
# 1984

# %%
sect_ind_df.true_sector.value_counts()
# Out:
# consumer_discr      392
# financials          340
# health_care         228
# industrials         212
# info_tech           208
# conumser_staples    148
# real_estate         128
# utilities           116
# energy              116
# materials            80
# telecomm             16
# Name: true_sector, dtype: int64

# %% [markdown]
# ## Merge time

# %%
with open('/Users/samfunk/ds/metis/project_mcnulty/datafiles/earnings_df.pkl', 'rb') as f :
    earnings_df = pickle.load(f)

with open('/Users/samfunk/ds/metis/project_mcnulty/datafiles/metrics.pkl', 'rb') as f:
    metrics_df = pickle.load(f)

master = metrics_df.join(earnings_df, how='left')
master = master.join(sect_ind_df, how='left')

# %% [markdown]
# ### Fill and remove various nans

# %%
master = master.reset_index()
master.rename(columns={'index': 'ticker_quarter'}, inplace=True)
master.loc[(master.currentR.isnull()) & (master.interest == 0), 'interest'] = 7.0
master['currentR'] = master['currentR'].fillna(1)
master['payout'] = master['payout'].fillna(0)
master.dropna(axis=0, inplace=True)

# %%
master
# Out:
#      ticker_quarter       date  bookvalue     fcf   intdebt      cash  \
# 0            AAPL_1 2017-07-01     25.490   1.171   20.8541    3.5747
# 1            AAPL_2 2017-04-01     25.658   1.827   18.8530    2.9004
# 2            AAPL_3 2016-12-31     24.986   4.477   16.5229    3.0896
# 3            AAPL_4 2016-09-24     23.896   2.264   16.2164    3.8167
# 4            MSFT_1 2017-06-30      9.382   1.130   11.1708   17.2344
# 5            MSFT_2 2017-03-31      9.026   1.161   10.8748   16.3130
# 6            MSFT_3 2016-12-31      8.873   0.555   10.9568   15.8325
# 7            MSFT_4 2016-09-30      9.035   1.205    9.5892   17.5802
# 8              FB_1 2017-06-30     22.924   1.350    0.0000    2.1559
# 9              FB_2 2017-03-31     21.511   1.310    0.0000    2.4573
# 10             FB_3 2016-12-31     20.546   1.764    0.0000    3.0902
# 11             FB_4 2016-09-30     18.849   0.865    0.0000    2.1031
# 12           AMZN_1 2017-06-30     48.463   2.772   16.0397   27.5637
# 13           AMZN_2 2017-03-31     45.438  -7.235   16.1237   32.3690
# 14           AMZN_3 2016-12-31     40.430  18.126   16.1300   40.5325
# 15           AMZN_4 2016-09-30     37.515   5.580   17.3101   28.8101
# 16            JNJ_1 2017-07-02     26.718   1.888   12.8430    4.6800
# 17            JNJ_2 2017-04-02     25.989   0.869   11.9597    7.7252
# 18            JNJ_3 2017-01-01     25.725   2.031    9.9098    6.9309
# 19            JNJ_4 2016-10-02     26.640   1.693    9.8803    6.6646
# 20           BRKB_1 2017-06-30    231.378   4.206   41.4351   10.7033
# 21           BRKB_2 2017-03-31    226.971  12.219   42.1585   39.1202
# 22           BRKB_3 2016-12-31    222.011   2.976   41.2153   11.3731
# 23           BRKB_4 2016-09-30    212.444   5.124   41.3174   34.4325
# 24            XOM_1 2017-06-30     42.286   0.908    9.8967    0.9539
# 25            XOM_2 2017-03-31     42.723   1.274   10.5165    1.1810
# 26            XOM_3 2016-12-31     40.351   0.846   10.3123    0.8819
# 1978        0.04       6.2          1.0           6.2         1.824549
# 1979        0.00       0.0          0.0           0.0             -inf
# 1980       -0.04     -10.0         -1.0          10.0         2.302585
# 1981        0.05      10.6          1.0          10.6         2.360854
# 1982       -0.04      -8.9         -1.0           8.9         2.186051
# 1983       -0.04      -5.6         -1.0           5.6         1.722767
# 1984        0.05      20.8          1.0          20.8         3.034953
# 1985       -0.02      -8.0         -1.0           8.0         2.079442
# 1986        0.03      75.0          1.0          75.0         4.317488
# 1987        0.04      57.1          1.0          57.1         4.044804
#
#       buckets                        mw_sector  \
# 0         1.0                       Technology
# 1         0.0                       Technology
# 2         0.0                       Technology
# 3         1.0                       Technology
# 4         1.0                       Technology
# 5         0.0                       Technology
# 6         0.0                       Technology
# 7         1.0                       Technology
# 8         1.0                       Technology
# 9         1.0                       Technology
# 10        1.0                       Technology
# 11        1.0                       Technology
# 12        1.0                 Retail/Wholesale
# 13        1.0                 Retail/Wholesale
# 14        1.0                 Retail/Wholesale
# 15        1.0                 Retail/Wholesale
# 16        0.0        Health Care/Life Sciences
# 17        0.0        Health Care/Life Sciences
# 18        0.0        Health Care/Life Sciences
# 19        0.0        Health Care/Life Sciences
# 20        0.0               Financial Services
# 21        0.0               Financial Services
# 22        1.0               Financial Services
# 23        1.0               Financial Services
# 24        1.0  Companies on the Energy Service
# 25        1.0  Companies on the Energy Service
# 26        1.0  Companies on the Energy Service
# 27        1.0  Companies on the Energy Service
# 28        1.0               Financial Services
# 29        1.0               Financial Services
# ...       ...                              ...
# 1958      1.0  Companies on the Energy Service
# 1959      1.0  Companies on the Energy Service
# 1960      0.0                 Retail/Wholesale
# 1961      0.0                 Retail/Wholesale
# 1962      0.0                 Retail/Wholesale
# 1963      1.0                 Retail/Wholesale
# 1964      1.0                 Retail/Wholesale
# 1965      0.0                 Retail/Wholesale
# 1966      1.0                 Retail/Wholesale
# 1967      1.0                 Retail/Wholesale
# 1968      0.0               Financial Services
# 1969      0.0               Financial Services
# 1970      1.0               Financial Services
# 1971      0.0               Financial Services
# 1972      1.0  Companies on the Energy Service
# 1973      0.0  Companies on the Energy Service
# 1974      1.0  Companies on the Energy Service
# 1975      1.0  Companies on the Energy Service
# 1976      1.0        Health Care/Life Sciences
# 1977      0.0        Health Care/Life Sciences
# 1978      1.0        Health Care/Life Sciences
# 1979      0.0        Health Care/Life Sciences
# 1980      1.0              Media/Entertainment
# 1981      1.0              Media/Entertainment
# 1982      1.0              Media/Entertainment
# 1983      1.0              Media/Entertainment
# 1984      1.0                   Consumer Goods
# 1985      1.0                   Consumer Goods
# 1986      1.0                   Consumer Goods
# 1987      1.0                   Consumer Goods
#
#                             industry     true_sector
# 0     Computers/Consumer Electronics  consumer_discr
# 1     Computers/Consumer Electronics  consumer_discr
# 2     Computers/Consumer Electronics  consumer_discr
# 3     Computers/Consumer Electronics  consumer_discr
# 4                           Software       info_tech
# 5                           Software       info_tech
# 6                           Software       info_tech
# 7                           Software       info_tech
# 8                    Internet/Online       info_tech
# 9                    Internet/Online       info_tech
# 10                   Internet/Online       info_tech
# 11                   Internet/Online       info_tech
# 12                   Mixed Retailing  consumer_discr
# 13                   Mixed Retailing  consumer_discr
# 14                   Mixed Retailing  consumer_discr
# 15                   Mixed Retailing  consumer_discr
# 16                   Pharmaceuticals     health_care
# 17                   Pharmaceuticals     health_care
# 18                   Pharmaceuticals     health_care
# 19                   Pharmaceuticals     health_care
# 20                       Reinsurance      financials
# 21                       Reinsurance      financials
# 22                       Reinsurance      financials
# 23                       Reinsurance      financials
# 24                   Major Oil & Gas          energy
# 25                   Major Oil & Gas          energy
# 26                   Major Oil & Gas          energy
# 27                   Major Oil & Gas          energy
# 28         Major International Banks      financials
# 29         Major International Banks      financials
# ...                              ...             ...
# 1958                  Oil Extraction          energy
# 1959                  Oil Extraction          energy
# 1960                 Clothing Retail  consumer_discr
# 1961                 Clothing Retail  consumer_discr
# 1962                 Clothing Retail  consumer_discr
# 1963                 Clothing Retail  consumer_discr
# 1964                 Clothing Retail  consumer_discr
# 1965                 Clothing Retail  consumer_discr
# 1966                 Clothing Retail  consumer_discr
# 1967                 Clothing Retail  consumer_discr
# 1968                Consumer Finance      financials
# 1969                Consumer Finance      financials
# 1970                Consumer Finance      financials
# 1971                Consumer Finance      financials
# 1972                  Oil Extraction          energy
# 1973                  Oil Extraction          energy
# 1974                  Oil Extraction          energy
# 1975                  Oil Extraction          energy
# 1976      Medical Equipment/Supplies     health_care
# 1977      Medical Equipment/Supplies     health_care
# 1978      Medical Equipment/Supplies     health_care
# 1979      Medical Equipment/Supplies     health_care
# 1980                    Broadcasting  consumer_discr
# 1981                    Broadcasting  consumer_discr
# 1982                    Broadcasting  consumer_discr
# 1983                    Broadcasting  consumer_discr
# 1984                        Clothing  consumer_discr
# 1985                        Clothing  consumer_discr
# 1986                        Clothing  consumer_discr
# 1987                        Clothing  consumer_discr
#
# [1936 rows x 22 columns]

# %% [markdown]
# ## Segment various features

# %% [markdown]
# ### Free Cash Flow

# %%
def fcf(row):
    if row['fcf'] < 0:
        return 0
    elif row['fcf'] < 1:
        return 1
    elif row['fcf'] < 2:
        return 2
    else:
        return 3

master['free_cash_flow'] = master.apply(lambda x: fcf(x), axis=1)

# %%
master.free_cash_flow.value_counts()
# Out:
# 1    759
# 2    442
# 0    372
# 3    363
# Name: free_cash_flow, dtype: int64

# %% [markdown]
# ### Dividends (payout ratio)

# %%
def divs(row):
    if row['payout'] < 0:
        return 0
    elif row['payout'] == 0:
        return 1
    else:
        return 2

master['dividends'] = master.apply(lambda x: divs(x), axis=1)

# %%
master.dividends.value_counts()
# Out:
# 2    1419
# 1     397
# 0     120
# Name: dividends, dtype: int64

# %% [markdown]
# ### Interest covereage (industry standard = 1.5)

# %%
def interest_coverage(row):
    if row['interest'] <= 1.5:
        return 0
    else:
        return 1
master.loc[master['interest'] == 0, ]
master['interest_coverage'] = master.apply(lambda x: interest_coverage(x), axis=1)

# %%
master.interest_coverage.value_counts()
# Out:
# 1    1602
# 0     334
# Name: interest_coverage, dtype: int64

# %% [markdown]
# ### Current ratio (industry standard < 1)

# %%
missing_currents = {'BRKB': 1.3,'GE': 2.16,'AXP': 1.96,'MET': 0.98,'SCHW': 0.33,'SPG': 0.27,'PRU': 1.19,'CI': 0.90,'AIG': 2.82,'DE': 2.12,'TRV': 0.40,'PLD': 1.14,'ALL': 0.45,'AFL': 0.40,'PSA': 1.11,'PGR': 1.00,'DLR': 0.77,'HCN': 1.53,'EQR': 0.26,'AVB': 0.92,'DFS': 1.53,'AMP': 2.58,'TROW': 3.36,'VTR': 0.92,'HIG': 4.35,'BXP': 2.96,'PFG': 2.66,'LNC': 3.24,'ESS': 0.70,'O': 0.61,'DHI': 7.22,'VNO': 6.28,'L': 0.52,'GGP': 1.58,'ETFC': 1.40,'HCP': 4.01,'MAA': 0.17,'UNM': 8.98,'CINF': 1.22,'LEN': 6.62,'X': 0.50,'ARE': 1.45,'RJF': 3.31,'SLG': 4.16,'DRE': 10.30,'UDR': 0.18,'EXR': 0.99,'RE': 2.00,'REG': 1.37,'FRT': 1.40,'WU': 0.29,'TMK': 0.32,'KIM': 2.57,'PHM': 4.27,'AIV': 0.18,'MAC': 0.68,'AIZ': 0.93,'NAVI': 34.22,
}

for x in master['ticker_quarter']:
    ticker = re.search(r'([A-Z]*)', x)[1]
    if ticker in missing_currents.keys():
        master.loc[master['ticker_quarter'] == x, 'currentR'] = missing_currents[ticker]
        
def current_ratio(row):
    if row['currentR'] < 1:
        return 0
    else:
        return 1

master['current_ratio'] = master.apply(lambda x: current_ratio(x), axis=1)

# %%
master.current_ratio.value_counts()
# Out:
# 1    1480
# 0     456
# Name: current_ratio, dtype: int64

# %% [markdown]
# ### Debt to Equity ratio (industry standard = 2)

# %%
def debt_to_equity(row):
    if row['debt_equity'] < 0:
        return 0
    elif row['debt_equity'] < 0.5:
        return 1
    elif row['debt_equity'] < 1:
        return 2
    else:
        return 3

master['debt_to_equity'] = master.apply(lambda x: debt_to_equity(x), axis=1)

# %%
master.debt_to_equity.value_counts()
# Out:
# 3    768
# 2    590
# 1    506
# 0     72
# Name: debt_to_equity, dtype: int64

# %% [markdown]
# ### Quality of income/earnings (industry standard ~ 1)

# %%
def income_quality(row):
    if row['incomeQ'] < 1:
        return 0
    else:
        return 1

master['income_quality'] = master.apply(lambda x: income_quality(x), axis=1)

# %%
master.income_quality.value_counts()
# Out:
# 1    1354
# 0     582
# Name: income_quality, dtype: int64

# %% [markdown]
# ### Research and Development as percentage of revenue (greater than or equal to 0)

# %%
def r_and_d(row):
    if row['rd'] <= 0:
        return 0
    else:
        return 1

master['r_and_d'] = master.apply(lambda x: r_and_d(x), axis=1)

# %%
master.r_and_d.value_counts()
# Out:
# 0    1381
# 1     555
# Name: r_and_d, dtype: int64

# %% [markdown]
# ### Save final/master df

# %%
with open('/Users/samfunk/ds/metis/project_mcnulty/datafiles/master_df.pkl', 'wb') as f:
    pickle.dump(master, f)

# %%
master
